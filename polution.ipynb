# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("air-pollution.csv")

# %%
data.head()
# Out:
#        Country  Year  Nitrogen Oxide  Sulphur Dioxide  Carbon Monoxide  \
# 0  Afghanistan  1750          555.42           139.42        142073.31
# 1  Afghanistan  1760          578.45           145.09        147859.24
# 2  Afghanistan  1770          602.42           150.99        153867.41
# 3  Afghanistan  1780          627.37           157.11        160104.42
# 4  Afghanistan  1790          653.34           163.46        166576.77
#
#    Organic Carbon    NMVOCs  Black Carbon  Ammonia
# 0         5456.88  13311.29       1633.03  7628.36
# 1         5679.12  13853.64       1699.54  7946.02
# 2         5909.88  14416.85       1768.60  8276.90
# 3         6149.44  15001.56       1840.29  8621.53
# 4         6398.04  15608.38       1914.68  8980.49

# %%
mean = data[ "Carbon Monoxide"].mean()

print(mean)
Afg = data.loc[(data["Country"] == "Afghanistan") ]
Afg.head()
mean1 = Afg["Carbon Monoxide"].mean()
print(mean1)
# Out:
# 5173732.871237825
# 376850.38053333334

# %%
Country = data.loc[(data["Country"] == "Afghanistan") & (data["Year"]) & (data["Carbon Monoxide"] > mean1)]
Country.head()
# Out:
#          Country  Year  Nitrogen Oxide  Sulphur Dioxide  Carbon Monoxide  \
# 112  Afghanistan  1907         2021.97           378.09        384482.88
# 114  Afghanistan  1909         2107.50           391.63        398040.48
# 116  Afghanistan  1911         2173.84           398.58        404881.89
# 118  Afghanistan  1913         2216.95           397.32        403366.88
# 120  Afghanistan  1915         2259.58           395.93        401722.44
#
#      Organic Carbon    NMVOCs  Black Carbon   Ammonia
# 112        14773.77  33047.97       4419.26  23517.81
# 114        15296.10  33355.29       4575.17  24025.02
# 116        15560.69  33061.92       4653.86  24339.43
# 118        15504.49  32082.71       4636.45  24454.84
# 120        15443.31  31100.19       4617.56  24569.47

# %%
Countrynorpt = data["Country"]

# %%
norpt = Countrynorpt.drop_duplicates()

# %%
for i in norpt:
    
    Country1 = data.loc[(data["Country"] == str(i))]

    
    mean2 = Country1["Carbon Monoxide"].max()
    
    Country2 = data.loc[(data["Country"] == str(i)) & (data["Year"]) & (data["Carbon Monoxide"] == mean2)]
    print(Country2)
# Out:
#          Country  Year  Nitrogen Oxide  Sulphur Dioxide  Carbon Monoxide  \
# 216  Afghanistan  2011       566105.71         34735.54       1351420.25
#
#      Organic Carbon     NMVOCs  Black Carbon    Ammonia
# 216        37646.28  345638.11      12842.11  150589.03
#     Country  Year  Nitrogen Oxide  Sulphur Dioxide  Carbon Monoxide  \
# 449  Africa  2019      6782872.66       6441732.21      99475754.55
#
#      Organic Carbon       NMVOCs  Black Carbon    Ammonia
# 449      3350540.97  26999339.45     1221962.0  8465804.0
# Empty DataFrame
# Columns: [Country, Year, Nitrogen Oxide, Sulphur Dioxide, Carbon Monoxide, Organic Carbon, NMVOCs, Black Carbon, Ammonia]
# Index: []
# Empty DataFrame
# Columns: [Country, Year, Nitrogen Oxide, Sulphur Dioxide, Carbon Monoxide, Organic Carbon, NMVOCs, Black Carbon, Ammonia]
# Index: []
#             Country  Year  Nitrogen Oxide  Sulphur Dioxide  Carbon Monoxide  \
# ...

# %%
Country.tail()
# Out:
#          Country  Year  Nitrogen Oxide  Sulphur Dioxide  Carbon Monoxide  \
# 216  Afghanistan  2011       566105.71         34735.54       1351420.25
# 218  Afghanistan  2013       421972.52         38664.04       1083912.75
# 220  Afghanistan  2015       436829.45         80922.94       1109626.58
# 222  Afghanistan  2017       420438.08        177784.83        985991.89
# 224  Afghanistan  2019       480669.59        327818.55       1055394.01
#
#      Organic Carbon     NMVOCs  Black Carbon    Ammonia
# 216        37646.28  345638.11      12842.11  150589.03
# 218        37852.00  282749.39      12678.51  159368.67
# 220        38991.15  286689.83      13220.73  168776.20
# 222        40198.84  260038.05      13677.53  177127.75
# 224        42136.77  269602.59      14917.44  185026.85
